# %% [markdown]
# # Portafolio de Certificaciones Databricks
#
# Este documento presenta de forma consolidada mis acreditaciones en Databricks y tecnologías asociadas.
#
#
# ---
#
# ## Perfil de Credenciales
#
# Acceso a todas mis certificaciones:
# https://credentials.databricks.com/profile/manuelanthonypardavepatio273770/wallet
#
#
# ---
#
# ## Certificaciones
#
# | Certificación | Enlace |
# |--------------|--------|
# | Databricks Fundamentals | https://credentials.databricks.com/75f40348-6e71-402d-83e0-c094f9f6a3f3 |
# | Generative AI Fundamentals | https://credentials.databricks.com/03132ebc-aa6a-4afc-af10-9f6b7db03742 |
# | AI Agent Fundamentals | https://credentials.databricks.com/92aee992-dfcb-4f38-8dac-3cae33ee759b |
# | Azure Databricks Platform Architect | https://credentials.databricks.com/39a1102d-3fb7-4877-b58e-4217656e6277 |
# | Stream Processing and Analysis with Apache Spark | https://credentials.databricks.com/c7c66bba-e3f0-44f1-874b-f6065ed91a04 |
